# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smf
import numpy as np

# %%
cars =pd.read_csv(r'C:\Users\saite\Downloads\Cars.csv')
cars.head()
# Out:
#    HP        MPG  VOL          SP         WT
# 0  49  53.700681   89  104.185353  28.762059
# 1  55  50.013401   92  105.461264  30.466833
# 2  55  50.013401   92  105.461264  30.193597
# 3  70  45.696322   92  113.461264  30.632114
# 4  53  50.504232   92  104.461264  29.889149

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   HP      81 non-null     int64
#  1   MPG     81 non-null     float64
#  2   VOL     81 non-null     int64
#  3   SP      81 non-null     float64
#  4   WT      81 non-null     float64
# dtypes: float64(3), int64(2)
# memory usage: 3.3 KB

# %%
cars.describe()
# Out:
#                HP        MPG         VOL          SP         WT
# count   81.000000  81.000000   81.000000   81.000000  81.000000
# mean   117.469136  34.422076   98.765432  121.540272  32.412577
# std     57.113502   9.131445   22.301497   14.181432   7.492813
# min     49.000000  12.101263   50.000000   99.564907  15.712859
# 25%     84.000000  27.856252   89.000000  113.829145  29.591768
# 50%    100.000000  35.152727  101.000000  118.208698  32.734518
# 75%    140.000000  39.531633  113.000000  126.404312  37.392524
# max    322.000000  53.700681  160.000000  169.598513  52.997752

# %%
cars.isna().sum()
# Out:
# HP     0
# MPG    0
# VOL    0
# SP     0
# WT     0
# dtype: int64

# %%
cars.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 76    False
# 77    False
# 78    False
# 79    False
# 80    False
# Length: 81, dtype: bool

# %%
cars.shape
# Out:
# (81, 5)

# %% [markdown]
# # correlation

# %%
cars.corr()
# Out:
#            HP       MPG       VOL        SP        WT
# HP   1.000000 -0.725038  0.077459  0.973848  0.076513
# MPG -0.725038  1.000000 -0.529057 -0.687125 -0.526759
# VOL  0.077459 -0.529057  1.000000  0.102170  0.999203
# SP   0.973848 -0.687125  0.102170  1.000000  0.102439
# WT   0.076513 -0.526759  0.999203  0.102439  1.000000

# %% [markdown]
# # EDA

# %%
from seaborn import scatterplot
import warnings
warnings.filterwarnings('ignore')

# %%
sns.distplot(x=cars['WT'])
plt.title('Distribution of weight of vehicles in thousand pounds')
plt.xlabel('Weight in thousand pounds')
plt.show()

# %%
sns.boxplot(x=cars['MPG'])
plt.show()

# %%
sns.boxplot(x=cars['HP'])
plt.show()

# %%
sns.boxplot(x=cars['WT'])
plt.show()

# %%
sns.boxplot(x=cars['SP'])
plt.show()

# %%
sns.boxplot(x=cars['VOL'])
plt.show()

# %%
scatterplot(x=cars['HP'],y=cars['VOL'])
plt.show()

# %%
scatterplot(x=cars['HP'],y=cars['WT'])
plt.show()

# %%
scatterplot(x=cars['HP'],y=cars['SP'])
plt.show()

# %%
sns.heatmap(np.abs(cars.corr()),cmap='Blues',annot=True)
plt.show()

# %%
import matplotlib.pyplot as plt


plt.bar(cars['SP'], cars['MPG'])

plt.xlabel('SP')
plt.ylabel('MPG')
plt.title('Bar Plot of SP vs MPG')

plt.show()

# %%
scatterplot(x=cars['WT'],y=cars['SP'])
plt.show()

# %%
scatterplot(x=cars['WT'],y=cars['VOL'])
plt.show()

# %%
scatterplot(x=cars['VOL'],y=cars['SP'])
plt.show()

# %%
scatterplot(x=cars['SP'],y=cars['WT'])
plt.show()

# %% [markdown]
#  Date 07/02/2025

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

cars[['HP','WT','VOl','SP']]=sc.fit_transform(cars[['HP','WT','VOL','SP']])

# %%
np.round(cars.describe(),2)
# Out:
#           HP    MPG     VOL     SP     WT    VOl
# count  81.00  81.00   81.00  81.00  81.00  81.00
# mean   -0.00  34.42   98.77   0.00   0.00   0.00
# std     1.01   9.13   22.30   1.01   1.01   1.01
# min    -1.21  12.10   50.00  -1.56  -2.24  -2.20
# 25%    -0.59  27.86   89.00  -0.55  -0.38  -0.44
# 50%    -0.31  35.15  101.00  -0.24   0.04   0.10
# 75%     0.40  39.53  113.00   0.35   0.67   0.64
# max     3.60  53.70  160.00   3.41   2.76   2.76

# %%
import statsmodels.formula.api as smf

# %%
ml_vol=smf.ols('MPG~VOL', data = cars).fit()
ml_vol.rsquared
np.round(ml_v.rsquared,2)
# Out:
# 0.28

# %%
ml_vol.params
# Out:
# Intercept    55.817089
# VOL          -0.216625
# dtype: float64

# %%
Y=B1*X1 +B0
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[154], line 1
# ----> 1 Y=B1*X1 +B0
#
# NameError: name 'B1' is not defined

# %%
ml_w=smf.ols('MPG~WT', data = cars).fit()
ml_w.rsquared
# Out:
# 0.2774751389270127

# %%
ml_w.params
# Out:
# Intercept    34.422076
# WT           -4.780288
# dtype: float64

# %%
ml_HP=smf.ols('MPG~HP', data = cars).fit()
ml_HP.rsquared
# Out:
# 0.5256806086282022

# %%
ml_SP=smf.ols('MPG~SP', data = cars).fit()
ml_SP.rsquared
# Out:
# 0.4721402334141217

# %%
model = smf.ols('MPG~WT+VOL+SP+HP',data=cars).fit

# %%
import statsmodels.api as sm, numpy as np
print(np.round(sm.OLS(np.random.rand(100), sm.add_constant(np.random.rand(100))).fit().rsquared, 2))
# Out:
# 0.0

# %%
model.params()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[164], line 1
# ----> 1 model.params()
#
# AttributeError: 'function' object has no attribute 'params'
